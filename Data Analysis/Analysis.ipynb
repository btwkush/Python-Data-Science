# %%
import pandas as pd

# %% [markdown]
# - creating dataset
#     - dictionary of items
#     - list of items
#     - import csv, excel, json files
# - read data
# - selection of data
# - cleaning the data
# - visualizing the data
# - saving the data

# %%
movies = {
    'title' : ['RRR','DDLJ','PK','KGF','YJDH'],
    'ratings' : [4.5,5.0,3.5,4.0,4.5],
    'year' : [2021, 2000, 2022, 2020, 2020]
}
pd.DataFrame(movies)
# Out:
#   title  ratings  year
# 0   RRR      4.5  2021
# 1  DDLJ      5.0  2000
# 2    PK      3.5  2022
# 3   KGF      4.0  2020
# 4  YJDH      4.5  2020

# %%
films = [
    {'title':'RRR','ratings':4.5,'year':2021},
    {'title':'DDLJ','ratings':5.0,'year':2000},
    {'title':'PK','ratings':3.5,'year':2022},
    {'title':'KGF','ratings':4.0,'year':2020},
    {'title':'YJHD','ratings':4.5,'year':2020}
]
pd.DataFrame(films)
# Out:
#   title  ratings  year
# 0   RRR      4.5  2021
# 1  DDLJ      5.0  2000
# 2    PK      3.5  2022
# 3   KGF      4.0  2020
# 4  YJHD      4.5  2020

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# GET BASIC INSIGHTS OF DATASET

# %%
df.head(20) #gives top 5 rows by default
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
df.tail(10) #gives bottom 5 rows b by default
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.sample(32)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1670   9521100960  20150116T000000   635000.0         4       1.50
# 18994  5632500110  20140716T000000   351000.0         3       1.00
# 3700   6700400110  20140702T000000   223000.0         3       2.00
# 3773   9348700490  20150410T000000   899000.0         4       2.50
# 837    8682262400  20150513T000000   419950.0         2       1.75
# 7855   3331500940  20140617T000000   342000.0         2       1.00
# 10502  1311900240  20141230T000000   226500.0         3       2.00
# 7660   6675500035  20140613T000000   435000.0         3       1.75
# 14364   546000910  20141203T000000   620000.0         3       1.75
# 13793  7302000120  20140610T000000   695000.0         3       2.50
# 20563   715010110  20140804T000000  1240420.0         5       3.25
# 8996    191100410  20140620T000000   970500.0         3       2.75
# 19137  3388110230  20140729T000000   179000.0         4       1.75
# ...

# %%
df.info() #gives info about data in concise form
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum() #to chrck null values in the data and sum their count
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe() #gives statistic of all the column
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# DATA SELECTION

# %% [markdown]
# - Row wise selection
#     - iloc - index based selection
#     - loc - label based selection
# - Column wise selection
#     - dictionary like slection
#     - object like selection

# %%
df.iloc[4]
# Out:
# id                    1954400510
# date             20150218T000000
# price                   510000.0
# bedrooms                       3
# bathrooms                    2.0
# sqft_living                 1680
# sqft_lot                    8080
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1680
# sqft_basement                  0
# yr_built                    1987
# yr_renovated                   0
# zipcode                    98074
# lat                      47.6168
# long                    -122.045
# sqft_living15               1800
# sqft_lot15                  7503
# Name: 4, dtype: object

# %%
df.iloc[[1,59,100]]
# Out:
#              id             date     price  bedrooms  bathrooms  sqft_living  \
# 1    6414100192  20141209T000000  538000.0         3       2.25         2570
# 59   8079040320  20150223T000000  430000.0         4       3.00         1850
# 100  1952200240  20140611T000000  850830.0         3       2.50         2070
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1        7242     2.0           0     0  ...      7        2170
# 59       9976     2.0           0     0  ...      8        1850
# 100     13241     1.5           0     0  ...      9        1270
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1              400      1951          1991    98125  47.7210 -122.319
# 59               0      1991             0    98059  47.5059 -122.149
# 100            800      1910             0    98102  47.6415 -122.315
#
#      sqft_living15  sqft_lot15
# 1             1690        7639
# 59            2270        8542
# ...

# %%
df.iloc[[1,59,100],[0,1,2]]
# Out:
#              id             date     price
# 1    6414100192  20141209T000000  538000.0
# 59   8079040320  20150223T000000  430000.0
# 100  1952200240  20140611T000000  850830.0

# %%
df.iloc[15:26]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 15  9297300055  20150124T000000   650000.0         4       3.00         2950
# 16  1875500060  20140731T000000   395000.0         3       2.00         1890
# 17  6865200140  20140529T000000   485000.0         4       1.00         1600
# 18    16000397  20141205T000000   189000.0         2       1.00         1200
# 19  7983200060  20150424T000000   230000.0         3       1.00         1250
# 20  6300500875  20140514T000000   385000.0         4       1.75         1620
# 21  2524049179  20140826T000000  2000000.0         3       2.75         3050
# 22  7137970340  20140703T000000   285000.0         5       2.50         2270
# 23  8091400200  20140516T000000   252700.0         2       1.50         1070
# 24  3814700200  20141120T000000   329000.0         3       2.25         2450
# 25  1202000200  20141103T000000   233000.0         3       2.00         1710
#
# ...

# %%
df = df.set_index('id')
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[7129300520]
# Out:
# date             20141013T000000
# price                   221900.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 7129300520, dtype: object

# %%
df.loc[[7129300520,1954400510]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3        1.0         1180
# 1954400510  20150218T000000  510000.0         3        2.0         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 1954400510      8080     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 1954400510           1800        7503

# %% [markdown]
# - Single Column Selection
#     - dictionary like selection
#     - object like selection
# - Multiple Column Selection
#     - dictionary like selection

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1680
# sqft_basement                  0
# yr_built                    1987
# yr_renovated                   0
# zipcode                    98074
# lat                      47.6168
# long                    -122.045
# sqft_living15               1800
# sqft_lot15                  7503
# Name: 1954400510, dtype: object

# %%
df.iloc[[1,59,100]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 8079040320  20150223T000000  430000.0         4       3.00         1850
# 1952200240  20140611T000000  850830.0         3       2.50         2070
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 6414100192      7242     2.0           0     0          3      7        2170
# 8079040320      9976     2.0           0     0          3      8        1850
# 1952200240     13241     1.5           0     0          5      9        1270
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 8079040320              0      1991             0    98059  47.5059 -122.149
# 1952200240            800      1910             0    98102  47.6415 -122.315
#
#             sqft_living15  sqft_lot15
# ...

# %%
df.iloc[[1,59,100],[0,1,2]]
# Out:
#                        date     price  bedrooms
# id
# 6414100192  20141209T000000  538000.0         3
# 8079040320  20150223T000000  430000.0         4
# 1952200240  20140611T000000  850830.0         3

# %%
df.iloc[15:26]
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 9297300055  20150124T000000   650000.0         4       3.00         2950
# 1875500060  20140731T000000   395000.0         3       2.00         1890
# 6865200140  20140529T000000   485000.0         4       1.00         1600
# 16000397    20141205T000000   189000.0         2       1.00         1200
# 7983200060  20150424T000000   230000.0         3       1.00         1250
# 6300500875  20140514T000000   385000.0         4       1.75         1620
# 2524049179  20140826T000000  2000000.0         3       2.75         3050
# 7137970340  20140703T000000   285000.0         5       2.50         2270
# 8091400200  20140516T000000   252700.0         2       1.50         1070
# 3814700200  20141120T000000   329000.0         3       2.25         2450
# 1202000200  20141103T000000   233000.0         3       2.00         1710
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
'''df = df.set_index('pclass')
df.head()'''
# Out:
# "df = df.set_index('pclass')\ndf.head()"

# %%
'''df.loc[3]'''
# Out:
# 'df.loc[3]'

# %%
'''df.loc[[3,1]]'''
# Out:
# 'df.loc[[3,1]]'

# %%
'''df['age']'''
# Out:
# "df['age']"

# %%
'''df.age'''
# Out:
# 'df.age'

# %%
'''df.loc[3]['age']'''
# Out:
# "df.loc[3]['age']"

# %% [markdown]
# Manipulating and Cleaning Data
#
# - removing rows and columns
# - rename column names
# - adding columns
# - changing datatypes
# - handling missing values
# - dropping missing values
# - using apply() method

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop = ['sqft_living', 'sqft_lot15']
df = df.drop(columns = cols_to_drop)
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15'],
#       dtype='object')

# %%
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_lot  floors  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00      5650     1.0
# 6414100192  20141209T000000  538000.0         3       2.25      7242     2.0
# 5631500400  20150225T000000  180000.0         2       1.00     10000     1.0
# 2487200875  20141209T000000  604000.0         4       3.00      5000     1.0
# 1954400510  20150218T000000  510000.0         3       2.00      8080     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 1954400510           0     0          3      8        1680              0
#
# ...

# %%
df.drop(labels = [1954400510], inplace=True)

# %%
df.head()
# Out:
#                        date      price  bedrooms  bathrooms  sqft_lot  floors  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00      5650     1.0
# 6414100192  20141209T000000   538000.0         3       2.25      7242     2.0
# 5631500400  20150225T000000   180000.0         2       1.00     10000     1.0
# 2487200875  20141209T000000   604000.0         4       3.00      5000     1.0
# 7237550310  20140512T000000  1225000.0         4       4.50    101930     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 7237550310           0     0          3     11        3890           1530
#
# ...

# %%
df.head(20)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_lot  floors  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00      5650     1.0
# 6414100192  20141209T000000   538000.0         3       2.25      7242     2.0
# 5631500400  20150225T000000   180000.0         2       1.00     10000     1.0
# 2487200875  20141209T000000   604000.0         4       3.00      5000     1.0
# 7237550310  20140512T000000  1225000.0         4       4.50    101930     1.0
# 1321400060  20140627T000000   257500.0         3       2.25      6819     2.0
# 2008000270  20150115T000000   291850.0         3       1.50      9711     1.0
# 2414600126  20150415T000000   229500.0         3       1.00      7470     1.0
# 3793500160  20150312T000000   323000.0         3       2.50      6560     2.0
# 1736800520  20150403T000000   662500.0         3       2.50      9796     1.0
# 9212900260  20140527T000000   468000.0         2       1.00      6000     1.0
# ...

# %%
name_update = {
    'lat' : 'latitude',
    'long' : 'longitude'
}
df.rename(columns = name_update, inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'latitude',
#        'longitude', 'sqft_living15'],
#       dtype='object')

# %%
df.yr_built.astype('float64')
# Out:
# id
# 7129300520    1955.0
# 6414100192    1951.0
# 5631500400    1933.0
# 2487200875    1965.0
# 7237550310    2001.0
#                ...
# 263000018     2009.0
# 6600060120    2014.0
# 1523300141    2009.0
# 291310100     2004.0
# 1523300157    2008.0
# Name: yr_built, Length: 21612, dtype: float64

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
avg_age = round(df['age'].mean())
print(avg_age)
# Out:
# 30

# %%
df['age'].fillna(avg_age, inplace=True)
df.head(20)
# Out:
# C:\Users\kush6\AppData\Local\Temp\ipykernel_21760\1887804755.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(avg_age, inplace=True)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# ...

# %%
df.dropna(subset=['embarked'], inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
cols_to_drop = ['deck']
df = df.drop(columns = cols_to_drop)
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    340
# Name: count, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df['embark_town'].value_counts().idxmax()
# Out:
# 'Southampton'

# %%
df['embark_town'].value_counts().idxmin()
# Out:
# 'Queenstown'
